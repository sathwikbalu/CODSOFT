# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\dlsat\Downloads\archive (9)\fraudTrain.csv")
data
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
# deleting columns
df = data.drop(columns=["Unnamed: 0","first","last","street","trans_num"],axis=1)
df
# Out:
#         trans_date_trans_time               cc_num  \
# 0         2019-01-01 00:00:18     2703186189652095
# 1         2019-01-01 00:00:44         630423337322
# 2         2019-01-01 00:00:51       38859492057661
# 3         2019-01-01 00:01:16     3534093764340240
# 4         2019-01-01 00:03:06      375534208663984
# ...                       ...                  ...
# 1296670   2020-06-21 12:12:08       30263540414123
# 1296671   2020-06-21 12:12:19     6011149206456997
# 1296672   2020-06-21 12:12:32     3514865930894695
# 1296673   2020-06-21 12:13:36     2720012583106919
# 1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt gender  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97      F
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23      F
# 2                       fraud_Lind-Buckridge  entertainment  220.11      M
# ...

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'gender', 'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job',
#        'dob', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# gender                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df["category"].unique()
# Out:
# array(['misc_net', 'grocery_pos', 'entertainment', 'gas_transport',
#        'misc_pos', 'grocery_net', 'shopping_net', 'shopping_pos',
#        'food_dining', 'personal_care', 'health_fitness', 'travel',
#        'kids_pets', 'home'], dtype=object)

# %%
df["cc_num"].unique()
# Out:
# array([   2703186189652095,        630423337322,      38859492057661,
#           3534093764340240,     375534208663984,    4767265376804500,
#             30074693890476,    6011360759745864,    4922710831011201,
#           2720830304681674,       4642894980163,     377234009633447,
#            180042946491150,    5559857416065248,    3514865930894695,
#           6011999606625827,    6011860238257910,    3565423334076143,
#           2348245054386329, 4956828990005111019, 4469777115158234880,
#           2305336922781618,     180048185037117,        630441765090,
#        4428780983793657331,     343464013864032,     374930071163758,
#           4334230547694630, 4225990116481262579,    4260059589824237,
#            180094608895855, 4599735407877245080,        630412733309,
#           2712209726293386,     374125201044065,     349612764943496,
#           3598215285024754,     213141712584544,      30561214688470,
# ...

# %%
df = df.drop(columns=["cc_num"],axis=1)
df
# Out:
#         trans_date_trans_time                             merchant  \
# 0         2019-01-01 00:00:18           fraud_Rippin, Kub and Mann
# 1         2019-01-01 00:00:44      fraud_Heller, Gutmann and Zieme
# 2         2019-01-01 00:00:51                 fraud_Lind-Buckridge
# 3         2019-01-01 00:01:16   fraud_Kutch, Hermiston and Farrell
# 4         2019-01-01 00:03:06                  fraud_Keeling-Crist
# ...                       ...                                  ...
# 1296670   2020-06-21 12:12:08                    fraud_Reichel Inc
# 1296671   2020-06-21 12:12:19             fraud_Abernathy and Sons
# 1296672   2020-06-21 12:12:32                 fraud_Stiedemann Ltd
# 1296673   2020-06-21 12:13:36  fraud_Reinger, Weissnat and Strosin
# 1296674   2020-06-21 12:13:37  fraud_Langosh, Wintheiser and Hyatt
#
#               category     amt gender                      city state    zip  \
# 0             misc_net    4.97      F            Moravian Falls    NC  28654
# ...

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'merchant', 'category', 'amt', 'gender',
#        'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob',
#        'unix_time', 'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
len(df["merchant"].unique().sum())
# Out:
# 16094

# %%
df.dtypes
# Out:
# trans_date_trans_time     object
# merchant                  object
# category                  object
# amt                      float64
# gender                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])

df['year'] = df['trans_date_trans_time'].dt.year
df['month'] = df['trans_date_trans_time'].dt.month
df['day'] = df['trans_date_trans_time'].dt.day
df['hour'] = df['trans_date_trans_time'].dt.hour
df['dayofweek'] = df['trans_date_trans_time'].dt.dayofweek
df['is_weekend'] = df['trans_date_trans_time'].dt.dayofweek >= 5

# %%
df = df.drop(columns=['trans_date_trans_time', 'dob', 'city', 'zip', 'unix_time'])

# %%
df.dtypes
# Out:
# merchant       object
# category       object
# amt           float64
# gender         object
# state          object
# lat           float64
# long          float64
# city_pop        int64
# job            object
# merch_lat     float64
# merch_long    float64
# is_fraud        int64
# year            int32
# month           int32
# day             int32
# hour            int32
# dayofweek       int32
# is_weekend       bool
# dtype: object

# %%
df["merchant"] = df["merchant"].astype('category')
df["merchant"] = df["merchant"].cat.codes
df["category"] = df["category"].astype('category')
df["category"] = df["category"].cat.codes
df["gender"] = df["gender"].astype('category')
df["gender"] = df["gender"].cat.codes
df["state"] = df["state"].astype('category')
df["state"] = df["state"].cat.codes
df["job"] = df["job"].astype('category')
df["job"] = df["job"].cat.codes
df["is_weekend"] = df["is_weekend"].astype('category')
df["is_weekend"] = df["is_weekend"].cat.codes
df.dtypes
# Out:
# merchant        int16
# category         int8
# amt           float64
# gender           int8
# state            int8
# lat           float64
# long          float64
# city_pop        int64
# job             int16
# merch_lat     float64
# merch_long    float64
# is_fraud        int64
# year            int32
# month           int32
# day             int32
# hour            int32
# dayofweek       int32
# is_weekend       int8
# dtype: object

# %%
len(df["city_pop"].unique())
# df["amt"].unique()
# Out:
# 879

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sb
sb.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sb.countplot(x='is_fraud',data = df,palette='hls')
# Out:
# C:\Users\dlsat\AppData\Local\Temp\ipykernel_12756\2339557397.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x='is_fraud',data = df,palette='hls')
# <Axes: xlabel='is_fraud', ylabel='count'>

# %%
df.columns
# Out:
# Index(['merchant', 'category', 'amt', 'gender', 'state', 'lat', 'long',
#        'city_pop', 'job', 'merch_lat', 'merch_long', 'is_fraud', 'year',
#        'month', 'day', 'hour', 'dayofweek', 'is_weekend'],
#       dtype='object')

# %%
y = df["is_fraud"].values
x = df.drop(columns=['is_fraud']).values
x,y
# Out:
# (array([[514.  ,   8.  ,   4.97, ...,   0.  ,   1.  ,   0.  ],
#         [241.  ,   4.  , 107.23, ...,   0.  ,   1.  ,   0.  ],
#         [390.  ,   0.  , 220.11, ...,   0.  ,   1.  ,   0.  ],
#         ...,
#         [599.  ,   1.  , 105.93, ...,  12.  ,   6.  ,   1.  ],
#         [509.  ,   1.  ,  74.9 , ...,  12.  ,   6.  ,   1.  ],
#         [370.  ,   1.  ,   4.3 , ...,  12.  ,   6.  ,   1.  ]]),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int64))

# %%
from sklearn.linear_model import LogisticRegression
regg = LogisticRegression()
regg.fit(x,y)
# Out:
# c:\Users\dlsat\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
data2 = pd.read_csv(r"C:\Users\dlsat\Downloads\archive (9)\fraudTest.csv")
data2
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
df2 = data2.drop(columns=["Unnamed: 0","first","last","street","trans_num","cc_num"],axis=1)

# %%
df2['trans_date_trans_time'] = pd.to_datetime(df2['trans_date_trans_time'])

df2['year'] = df2['trans_date_trans_time'].dt.year
df2['month'] = df2['trans_date_trans_time'].dt.month
df2['day'] = df2['trans_date_trans_time'].dt.day
df2['hour'] = df2['trans_date_trans_time'].dt.hour
df2['dayofweek'] = df2['trans_date_trans_time'].dt.dayofweek
df2['is_weekend'] = df2['trans_date_trans_time'].dt.dayofweek >= 5
df2 = df2.drop(columns=['trans_date_trans_time', 'dob', 'city', 'zip', 'unix_time'])

# %%
df2["merchant"] = df2["merchant"].astype('category')
df2["merchant"] = df2["merchant"].cat.codes
df2["category"] = df2["category"].astype('category')
df2["category"] = df2["category"].cat.codes
df2["gender"] = df2["gender"].astype('category')
df2["gender"] = df2["gender"].cat.codes
df2["state"] = df2["state"].astype('category')
df2["state"] = df2["state"].cat.codes
df2["job"] = df2["job"].astype('category')
df2["job"] = df2["job"].cat.codes
df2["is_weekend"] = df2["is_weekend"].astype('category')
df2["is_weekend"] = df2["is_weekend"].cat.codes

# %%
y_test = df2['is_fraud'].values
x_test = df2.drop(columns=['is_fraud']).values
x_test,y_test
# Out:
# (array([[319.  ,  10.  ,   2.86, ...,  12.  ,   6.  ,   1.  ],
#         [591.  ,  10.  ,  29.84, ...,  12.  ,   6.  ,   1.  ],
#         [611.  ,   5.  ,  41.28, ...,  12.  ,   6.  ,   1.  ],
#         ...,
#         [496.  ,   7.  ,  86.88, ...,  23.  ,   3.  ,   0.  ],
#         [ 75.  ,  13.  ,   7.99, ...,  23.  ,   3.  ,   0.  ],
#         [125.  ,   0.  ,  38.13, ...,  23.  ,   3.  ,   0.  ]]),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int64))

# %%
y_pred=regg.predict(x_test)
from sklearn.metrics import confusion_matrix
confusion_matrix=confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[553216,    358],
#        [  2145,      0]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy_score of logistic regression:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy_score of logistic regression: 0.9954959250988359

# %%
from sklearn.ensemble import RandomForestClassifier
classifier1 = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier1.fit(x, y)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
res=accuracy_score(y_test, y_pred)
print("random forest",res)
# Out:
# random forest 0.9981357484628023
